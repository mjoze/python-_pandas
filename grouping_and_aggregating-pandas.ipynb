# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv')
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
# 3                      Employed full-time           United States
# 4                      Employed full-time                 Ukraine
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
# 2              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  \
# 0                                                NaN
# 1                                                NaN
# 2                      Web development or web design
# 3  Computer science, computer engineering, or sof...
# 4  Computer science, computer engineering, or sof...
#
#                                             EduOther  \
# 0  Taught yourself a new language, framework, or ...
# 1  Taken an online course in programming or softw...
# 2  Taught yourself a new language, framework, or ...
# 3  Taken an online course in programming or softw...
# 4  Taken an online course in programming or softw...
#
#                     OrgSize  \
# 0                       NaN
# 1                       NaN
# 2      100 to 499 employees
# 3      100 to 499 employees
# 4  10,000 or more employees
#
#                                              DevType YearsCode Age1stCode  \
# 0                                                NaN         4         10
# 1  Developer, desktop or enterprise applications;...       NaN         17
# 2  Designer;Developer, back-end;Developer, front-...         3         22
# 3                              Developer, full-stack         3         16
# 4  Academic researcher;Developer, desktop or ente...        16         14
#
#        YearsCodePro           CareerSat                 JobSat  \
# 0               NaN                 NaN                    NaN
# 1               NaN                 NaN                    NaN
# 2                 1  Slightly satisfied     Slightly satisfied
# 3  Less than 1 year      Very satisfied     Slightly satisfied
# 4                 9   Very dissatisfied  Slightly dissatisfied
#
#                MgrIdiot  MgrMoney   MgrWant  \
# 0                   NaN       NaN       NaN
# 1                   NaN       NaN       NaN
# 2  Not at all confident  Not sure  Not sure
# 3        Very confident        No  Not sure
# 4    Somewhat confident       Yes        No
#
#                                              JobSeek          LastHireDate  \
# 0                                                NaN                   NaN
# 1                    I am actively looking for a job  I've never had a job
# 2  I’m not actively looking, but I am open to new...         1-2 years ago
# 3       I am not interested in new job opportunities  Less than a year ago
# 4       I am not interested in new job opportunities  Less than a year ago
#
#                                              LastInt FizzBuzz  \
# 0                                                NaN      NaN
# 1                                                NaN      NaN
# 2                Interview with people in peer roles       No
# 3  Write code by hand (e.g., on a whiteboard);Int...       No
# 4  Write any code;Write code by hand (e.g., on a ...       No
#
#                                           JobFactors  \
# 0                                                NaN
# 1  Financial performance or funding status of the...
# 2  Languages, frameworks, and other technologies ...
# 3  Languages, frameworks, and other technologies ...
# 4  Industry that I'd be working in;Languages, fra...
#
#                                         ResumeUpdate CurrencySymbol  \
# 0                                                NaN            NaN
# 1  Something else changed (education, award, medi...            NaN
# 2                   I was preparing for a job search            THB
# 3                   I was preparing for a job search            USD
# 4                   I was preparing for a job search            UAH
#
#            CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# 0                   NaN        NaN      NaN            NaN          NaN
# 1                   NaN        NaN      NaN            NaN          NaN
# 2             Thai baht    23000.0  Monthly         8820.0         40.0
# 3  United States dollar    61000.0   Yearly        61000.0         80.0
# 4     Ukrainian hryvnia        NaN      NaN            NaN         55.0
#
#                                             WorkPlan  \
# 0                                                NaN
# 1                                                NaN
# 2  There's no schedule or spec; I work on what se...
# 3  There's no schedule or spec; I work on what se...
# 4  There is a schedule and/or spec (made by me or...
#
#                                        WorkChallenge  \
# 0                                                NaN
# 1                                                NaN
# 2  Distracting work environment;Inadequate access...
# 3                                                NaN
# 4  Being tasked with non-development work;Inadequ...
#
#                          WorkRemote WorkLoc                  ImpSyn  \
# 0                               NaN     NaN                     NaN
# 1                               NaN     NaN                     NaN
# 2  Less than once per month / Never    Home                 Average
# 3  Less than once per month / Never    Home  A little below average
# 4             A few days each month  Office  A little above average
#
#                                    CodeRev  CodeRevHrs  \
# 0                                      NaN         NaN
# 1                                      NaN         NaN
# 2                                       No         NaN
# 3                                       No         NaN
# 4  Yes, because I see value in code review         NaN
#
#                        UnitTests  \
# 0                            NaN
# 1                            NaN
# 2      No, but I think we should
# 3      No, but I think we should
# 4  Yes, it's part of our process
#
#                                          PurchaseHow  \
# 0                                                NaN
# 1                                                NaN
# 2                                           Not sure
# 3  Developers typically have the most influence o...
# 4                                           Not sure
#
#                     PurchaseWhat                           LanguageWorkedWith  \
# 0                            NaN              HTML/CSS;Java;JavaScript;Python
# 1                            NaN                          C++;HTML/CSS;Python
# 2  I have little or no influence                                     HTML/CSS
# 3  I have little or no influence                          C;C++;C#;Python;SQL
# 4  I have little or no influence  C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#
#                             LanguageDesireNextYear  \
# 0  C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 1                      C++;HTML/CSS;JavaScript;SQL
# 2                                  Elixir;HTML/CSS
# 3                              C;C#;JavaScript;SQL
# 4         HTML/CSS;Java;JavaScript;SQL;WebAssembly
#
#                                  DatabaseWorkedWith  \
# 0                                            SQLite
# 1                                               NaN
# 2                                        PostgreSQL
# 3                                      MySQL;SQLite
# 4  Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
#
#                               DatabaseDesireNextYear  \
# 0                                              MySQL
# 1                                              MySQL
# 2                                         PostgreSQL
# 3                                       MySQL;SQLite
# 4  Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
#
#                   PlatformWorkedWith                 PlatformDesireNextYear  \
# 0                      MacOS;Windows                Android;Arduino;Windows
# 1                            Windows                                Windows
# 2                                NaN                                    NaN
# 3                      Linux;Windows                          Linux;Windows
# 4  Android;Linux;MacOS;Slack;Windows  Android;Docker;Kubernetes;Linux;Slack
#
#                             WebFrameWorkedWith        WebFrameDesireNextYear  \
# 0                                 Django;Flask                  Flask;jQuery
# 1                                       Django                        Django
# 2                                          NaN                     Other(s):
# 3                                          NaN                           NaN
# 4  Django;Express;Flask;jQuery;React.js;Spring  Flask;jQuery;React.js;Spring
#
#   MiscTechWorkedWith                    MiscTechDesireNextYear  \
# 0            Node.js                                   Node.js
# 1                NaN                                       NaN
# 2                NaN                                       NaN
# 3               .NET                                      .NET
# 4    Cordova;Node.js  Apache Spark;Hadoop;Node.js;React Native
#
#                                      DevEnviron        OpSys  \
# 0                    IntelliJ;Notepad++;PyCharm      Windows
# 1                                  Atom;PyCharm      Windows
# 2                        Vim;Visual Studio Code  Linux-based
# 3  Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 4                        IntelliJ;Notepad++;Vim  Linux-based
#
#                                Containers BlockchainOrg  \
# 0                 I do not use containers           NaN
# 1                 I do not use containers           NaN
# 2                 I do not use containers           NaN
# 3                 I do not use containers    Not at all
# 4  Outside of work, for personal projects    Not at all
#
#                                         BlockchainIs BetterLife  \
# 0                                                NaN        Yes
# 1  Useful across many domains and could change ma...        Yes
# 2                                                NaN        Yes
# 3  Useful for decentralized currency (i.e., Bitcoin)        Yes
# 4                                                NaN        Yes
#
#                                    ITperson OffOn SocialMedia  \
# 0  Fortunately, someone else has that title   Yes     Twitter
# 1                                       Yes   Yes   Instagram
# 2                                       Yes   Yes      Reddit
# 3                                      SIGH   Yes      Reddit
# 4                                  Also Yes   Yes    Facebook
#
#                Extraversion ScreenName        SOVisit1st  \
# 0                    Online   Username              2017
# 1                    Online   Username              2017
# 2  In real life (in person)   Username              2011
# 3  In real life (in person)   Username              2014
# 4  In real life (in person)   Username  I don't remember
#
#                        SOVisitFreq  \
# 0  A few times per month or weekly
# 1            Daily or almost daily
# 2             A few times per week
# 3            Daily or almost daily
# 4           Multiple times per day
#
#                                            SOVisitTo  \
# 0  Find answers to specific questions;Learn how t...
# 1  Find answers to specific questions;Learn how t...
# 2  Find answers to specific questions;Learn how t...
# 3  Find answers to specific questions;Pass the ti...
# 4                 Find answers to specific questions
#
#                   SOFindAnswer                     SOTimeSaved  SOHowMuchTime  \
# 0           3-5 times per week  Stack Overflow was much faster  31-60 minutes
# 1           3-5 times per week  Stack Overflow was much faster  11-30 minutes
# 2          6-10 times per week        They were about the same            NaN
# 3           1-2 times per week  Stack Overflow was much faster  31-60 minutes
# 4  More than 10 times per week  Stack Overflow was much faster            NaN
#
#   SOAccount                           SOPartFreq  \
# 0        No                                  NaN
# 1       Yes      A few times per month or weekly
# 2       Yes  Less than once per month or monthly
# 3       Yes  Less than once per month or monthly
# 4       Yes      A few times per month or weekly
#
#                                               SOJobs  \
# 0  No, I didn't know that Stack Overflow had a jo...
# 1  No, I knew that Stack Overflow had a job board...
# 2                                                Yes
# 3                                                Yes
# 4  No, I knew that Stack Overflow had a job board...
#
#                                             EntTeams           SOComm  \
# 0                No, and I don't know what those are          Neutral
# 1                No, and I don't know what those are    Yes, somewhat
# 2  No, I've heard of them, but I am not part of a...          Neutral
# 3                No, and I don't know what those are   No, not really
# 4  No, I've heard of them, but I am not part of a...  Yes, definitely
#
#                              WelcomeChange  \
# 0  Just as welcome now as I felt last year
# 1  Just as welcome now as I felt last year
# 2  Just as welcome now as I felt last year
# 3  Just as welcome now as I felt last year
# 4  Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
# 1  Tech articles written by other developers;Indu...  19.0    Man    No
# 2  Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3  Tech articles written by other developers;Indu...  22.0    Man    No
# 4  Tech meetups or events in your area;Courses on...  30.0    Man    No
#
#                  Sexuality                                 Ethnicity  \
# 0  Straight / Heterosexual                                       NaN
# 1  Straight / Heterosexual                                       NaN
# 2  Straight / Heterosexual                                       NaN
# 3  Straight / Heterosexual              White or of European descent
# 4  Straight / Heterosexual  White or of European descent;Multiracial
#
#   Dependents           SurveyLength                  SurveyEase
# 0         No  Appropriate in length  Neither easy nor difficult
# 1         No  Appropriate in length  Neither easy nor difficult
# 2        Yes  Appropriate in length  Neither easy nor difficult
# 3         No  Appropriate in length                        Easy
# 4         No  Appropriate in length                        Easy

# %%
df['ConvertedComp'].head(15)
# Out:
# 0          NaN
# 1          NaN
# 2       8820.0
# 3      61000.0
# 4          NaN
# 5     366420.0
# 6          NaN
# 7          NaN
# 8      95179.0
# 9      13293.0
# 10         NaN
# 11         NaN
# 12     90000.0
# 13     57060.0
# 14         NaN
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].median()
# Out:
# 57287.0

# %%
df.median()
# Out:
# Respondent       44442.0
# CompTotal        62000.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
df.describe()
# Out:
#          Respondent     CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04   5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11   1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13   2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00   0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04   2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04   5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05   1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16   2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
df['ConvertedComp'].count()
# Out:
# 55823

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia']
# Out:
# 0          Twitter
# 1        Instagram
# 2           Reddit
# 3           Reddit
# 4         Facebook
#            ...
# 88878      YouTube
# 88879          NaN
# 88880          NaN
# 88881          NaN
# 88882     WhatsApp
# Name: SocialMedia, Length: 88883, dtype: object

# %%
schema_df.loc['SocialMedia']

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
df['Country']
# Out:
# 0                United Kingdom
# 1        Bosnia and Herzegovina
# 2                      Thailand
# 3                 United States
# 4                       Ukraine
#                   ...
# 88878                    Canada
# 88879                       NaN
# 88880                       NaN
# 88881                       NaN
# 88882                     Spain
# Name: Country, Length: 88883, dtype: object

# %%
df['Country'].value_counts()
# Out:
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# Saint Kitts and Nevis                   1
# Saint Vincent and the Grenadines        1
# Sao Tome and Principe                   1
# Timor-Leste                             1
# Tonga                                   1
# Name: Country, Length: 179, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('Poland')
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 51             52  I am a developer by profession      Yes
# 80             81  I am a developer by profession      Yes
# 190           192  I am a developer by profession      Yes
# 192           194  I am a developer by profession      Yes
# 228           230  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 88318       88871  I am a developer by profession      Yes
# 88431       18256                             NaN       No
# 88449       22192                             NaN       No
# 88728       62177                             NaN      Yes
# 88837       81994                             NaN      Yes
#
#                                              OpenSourcer  \
# 51                            Once a month or more often
# 80     Less than once a month but more than once per ...
# 190                                                Never
# 192                                                Never
# 228                                                Never
# ...                                                  ...
# 88318                            Less than once per year
# 88431                            Less than once per year
# 88449                         Once a month or more often
# 88728                            Less than once per year
# 88837                                              Never
#
#                                               OpenSource  \
# 51     OSS is, on average, of HIGHER quality than pro...
# 80     The quality of OSS and closed source software ...
# 190    The quality of OSS and closed source software ...
# 192    OSS is, on average, of HIGHER quality than pro...
# 228    OSS is, on average, of LOWER quality than prop...
# ...                                                  ...
# 88318  The quality of OSS and closed source software ...
# 88431  The quality of OSS and closed source software ...
# 88449  OSS is, on average, of HIGHER quality than pro...
# 88728  OSS is, on average, of LOWER quality than prop...
# 88837  The quality of OSS and closed source software ...
#
#                                               Employment Country  \
# 51                                    Employed full-time  Poland
# 80                                    Employed full-time  Poland
# 190                                   Employed full-time  Poland
# 192                                   Employed full-time  Poland
# 228                                   Employed full-time  Poland
# ...                                                  ...     ...
# 88318                                 Employed full-time  Poland
# 88431                                 Employed full-time  Poland
# 88449  Independent contractor, freelancer, or self-em...  Poland
# 88728                                 Employed full-time  Poland
# 88837                                 Employed part-time  Poland
#
#               Student                                            EdLevel  \
# 51                 No  Some college/university study without earning ...
# 80                 No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 190    Yes, full-time        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 192                No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 228               NaN  Some college/university study without earning ...
# ...               ...                                                ...
# 88318  Yes, part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88431              No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88449              No                                                NaN
# 88728             NaN  Secondary school (e.g. American high school, G...
# 88837  Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                           UndergradMajor  \
# 51     Computer science, computer engineering, or sof...
# 80     Computer science, computer engineering, or sof...
# 190                            Mathematics or statistics
# 192    Computer science, computer engineering, or sof...
# 228    Information systems, information technology, o...
# ...                                                  ...
# 88318  Information systems, information technology, o...
# 88431                                                NaN
# 88449  A natural science (ex. biology, chemistry, phy...
# 88728                                                NaN
# 88837  Computer science, computer engineering, or sof...
#
#                                                 EduOther  \
# 51     Taught yourself a new language, framework, or ...
# 80     Taken an online course in programming or softw...
# 190    Taken an online course in programming or softw...
# 192    Taken an online course in programming or softw...
# 228    Taken an online course in programming or softw...
# ...                                                  ...
# 88318  Taught yourself a new language, framework, or ...
# 88431  Completed an industry certification program (e...
# 88449  Taken an online course in programming or softw...
# 88728                                                NaN
# 88837  Taken an online course in programming or softw...
#
#                                                  OrgSize  \
# 51                                    20 to 99 employees
# 80                              10,000 or more employees
# 190                                   10 to 19 employees
# 192                                   10 to 19 employees
# 228                             10,000 or more employees
# ...                                                  ...
# 88318                                 20 to 99 employees
# 88431                               100 to 499 employees
# 88449  Just me - I am a freelancer, sole proprietor, ...
# 88728                           10,000 or more employees
# 88837                               100 to 499 employees
#
#                                                  DevType           YearsCode  \
# 51                 Developer, back-end;DevOps specialist                  12
# 80                                 Developer, full-stack                  20
# 190    Data scientist or machine learning specialist;...                   6
# 192    Developer, back-end;Developer, embedded applic...                  11
# 228    Developer, back-end;Developer, desktop or ente...                  10
# ...                                                  ...                 ...
# 88318  Developer, back-end;Developer, embedded applic...                   5
# 88431                                           Educator                 NaN
# 88449                       Academic researcher;Educator                  12
# 88728                                                NaN  More than 50 years
# 88837              Developer, back-end;Scientist;Student                   4
#
#           Age1stCode        YearsCodePro              CareerSat  \
# 51                 8                   1         Very satisfied
# 80                 7                   5         Very satisfied
# 190               13                   2  Slightly dissatisfied
# 192               17                   5         Very satisfied
# 228               10                   2  Slightly dissatisfied
# ...              ...                 ...                    ...
# 88318             15                   2      Very dissatisfied
# 88431            NaN                 NaN                    NaN
# 88449              7                  10                    NaN
# 88728  Older than 85  More than 50 years                    NaN
# 88837             19                   1                    NaN
#
#                       JobSat              MgrIdiot  MgrMoney   MgrWant  \
# 51        Slightly satisfied        Very confident  Not sure  Not sure
# 80            Very satisfied        Very confident        No        No
# 190    Slightly dissatisfied  Not at all confident  Not sure  Not sure
# 192       Slightly satisfied    Somewhat confident  Not sure        No
# 228    Slightly dissatisfied    Somewhat confident        No        No
# ...                      ...                   ...       ...       ...
# 88318      Very dissatisfied        Very confident  Not sure  Not sure
# 88431                    NaN        Very confident  Not sure  Not sure
# 88449                    NaN                   NaN       NaN       NaN
# 88728                    NaN    Somewhat confident       Yes       Yes
# 88837                    NaN    Somewhat confident  Not sure  Not sure
#
#                                                  JobSeek  \
# 51     I’m not actively looking, but I am open to new...
# 80          I am not interested in new job opportunities
# 190    I’m not actively looking, but I am open to new...
# 192    I’m not actively looking, but I am open to new...
# 228    I’m not actively looking, but I am open to new...
# ...                                                  ...
# 88318       I am not interested in new job opportunities
# 88431                                                NaN
# 88449                                                NaN
# 88728                                                NaN
# 88837                                                NaN
#
#                LastHireDate  \
# 51            1-2 years ago
# 80            1-2 years ago
# 190           1-2 years ago
# 192           1-2 years ago
# 228           1-2 years ago
# ...                     ...
# 88318  Less than a year ago
# 88431                   NaN
# 88449                   NaN
# 88728                   NaN
# 88837                   NaN
#
#                                                  LastInt FizzBuzz  \
# 51                                                   NaN       No
# 80     Write any code;Interview with people in peer r...       No
# 190    Write any code;Interview with people in peer r...       No
# 192    Write any code;Interview with people in peer r...       No
# 228    Write any code;Write code by hand (e.g., on a ...       No
# ...                                                  ...      ...
# 88318                  Solve a brain-teaser style puzzle       No
# 88431                                                NaN      NaN
# 88449                                                NaN      NaN
# 88728                                                NaN      NaN
# 88837                                                NaN      NaN
#
#                                               JobFactors  \
# 51                                                   NaN
# 80     Industry that I'd be working in;Opportunities ...
# 190    Industry that I'd be working in;Languages, fra...
# 192    Specific department or team I'd be working on;...
# 228    Office environment or company culture;Opportun...
# ...                                                  ...
# 88318  Languages, frameworks, and other technologies ...
# 88431                                                NaN
# 88449                                                NaN
# 88728                                                NaN
# 88837                                                NaN
#
#                                             ResumeUpdate CurrencySymbol  \
# 51                      I was preparing for a job search            PLN
# 80                      I was preparing for a job search            PLN
# 190                     I was preparing for a job search            PLN
# 192                     I was preparing for a job search            PLN
# 228    Something else changed (education, award, medi...            PLN
# ...                                                  ...            ...
# 88318   My job status changed (promotion, new job, etc.)            PLN
# 88431                                                NaN            NaN
# 88449                                                NaN            NaN
# 88728                                                NaN            NaN
# 88837                                                NaN            NaN
#
#        CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# 51     Polish zloty    12320.0  Monthly        39504.0         40.0
# 80     Polish zloty        NaN      NaN            NaN          NaN
# 190    Polish zloty     9000.0  Monthly        28860.0         40.0
# 192    Polish zloty     4000.0  Monthly        12828.0         40.0
# 228    Polish zloty        NaN  Monthly            NaN         40.0
# ...             ...        ...      ...            ...          ...
# 88318  Polish zloty     5000.0  Monthly        16032.0        168.0
# 88431           NaN        NaN      NaN            NaN          NaN
# 88449           NaN        NaN      NaN            NaN          NaN
# 88728           NaN        NaN      NaN            NaN          NaN
# 88837           NaN        NaN      NaN            NaN          NaN
#
#                                                 WorkPlan  \
# 51     There's no schedule or spec; I work on what se...
# 80                                                   NaN
# 190    There is a schedule and/or spec (made by me or...
# 192    There's no schedule or spec; I work on what se...
# 228    There is a schedule and/or spec (made by me or...
# ...                                                  ...
# 88318  There's no schedule or spec; I work on what se...
# 88431                                                NaN
# 88449                                                NaN
# 88728                                                NaN
# 88837                                                NaN
#
#                                            WorkChallenge  \
# 51                         Meetings;Time spent commuting
# 80                                                   NaN
# 190          Meetings;Not enough people for the workload
# 192    Being tasked with non-development work;Meeting...
# 228    Distracting work environment;Meetings;Time spe...
# ...                                                  ...
# 88318  Being tasked with non-development work;Distrac...
# 88431                                                NaN
# 88449                                                NaN
# 88728                                                NaN
# 88837                                                NaN
#
#                              WorkRemote WorkLoc                  ImpSyn  \
# 51     Less than once per month / Never  Office  A little above average
# 80     Less than once per month / Never  Office       Far above average
# 190               A few days each month  Office  A little above average
# 192               A few days each month  Office  A little above average
# 228    Less than once per month / Never  Office  A little below average
# ...                                 ...     ...                     ...
# 88318             A few days each month  Office  A little above average
# 88431                               NaN     NaN                     NaN
# 88449                               NaN     NaN                     NaN
# 88728                               NaN     NaN                     NaN
# 88837                               NaN     NaN                     NaN
#
#                                        CodeRev  CodeRevHrs  \
# 51            Yes, because I was told to do so         4.0
# 80     Yes, because I see value in code review         NaN
# 190    Yes, because I see value in code review         2.0
# 192                                         No         NaN
# 228    Yes, because I see value in code review         2.0
# ...                                        ...         ...
# 88318  Yes, because I see value in code review         4.0
# 88431                                      NaN         NaN
# 88449                                      NaN         NaN
# 88728                                      NaN         NaN
# 88837                                      NaN         NaN
#
#                                                UnitTests  \
# 51                         Yes, it's part of our process
# 80                         Yes, it's part of our process
# 190                            No, but I think we should
# 192                            No, but I think we should
# 228    Yes, it's not part of our process but the deve...
# ...                                                  ...
# 88318                          No, but I think we should
# 88431                                                NaN
# 88449                                                NaN
# 88728                                                NaN
# 88837                                                NaN
#
#                                              PurchaseHow  \
# 51     Developers typically have the most influence o...
# 80                                              Not sure
# 190                                             Not sure
# 192    Developers and management have nearly equal in...
# 228                                             Not sure
# ...                                                  ...
# 88318                                           Not sure
# 88431                                                NaN
# 88449                                                NaN
# 88728                                                NaN
# 88837                                                NaN
#
#                            PurchaseWhat  \
# 51                I have some influence
# 80        I have little or no influence
# 190               I have some influence
# 192               I have some influence
# 228       I have little or no influence
# ...                                 ...
# 88318  I have a great deal of influence
# 88431                               NaN
# 88449                               NaN
# 88728                               NaN
# 88837                               NaN
#
#                                       LanguageWorkedWith  \
# 51     Bash/Shell/PowerShell;C;C++;Elixir;Erlang;Go;H...
# 80           Assembly;Bash/Shell/PowerShell;C;C++;Python
# 190              Bash/Shell/PowerShell;JavaScript;Python
# 192    Assembly;Bash/Shell/PowerShell;C;HTML/CSS;Java...
# 228                      Bash/Shell/PowerShell;Go;Python
# ...                                                  ...
# 88318  C++;C#;HTML/CSS;Java;JavaScript;Python;SQL;Typ...
# 88431                                                NaN
# 88449                      Clojure;Elixir;Python;R;Scala
# 88728  Assembly;Bash/Shell/PowerShell;C;C++;C#;Clojur...
# 88837                             Erlang;Java;Python;SQL
#
#                                   LanguageDesireNextYear  \
# 51                                                  Rust
# 80                  Assembly;Bash/Shell/PowerShell;C;C++
# 190                   Bash/Shell/PowerShell;Python;Scala
# 192            Bash/Shell/PowerShell;C;HTML/CSS;Java;PHP
# 228                 Bash/Shell/PowerShell;Go;Java;Python
# ...                                                  ...
# 88318  Bash/Shell/PowerShell;C++;C#;HTML/CSS;Java;Jav...
# 88431                                                NaN
# 88449                                          Other(s):
# 88728  Assembly;Bash/Shell/PowerShell;C;C++;C#;Clojur...
# 88837                                  Java;Python;Scala
#
#                                       DatabaseWorkedWith  \
# 51                             MariaDB;PostgreSQL;SQLite
# 80                                                   NaN
# 190                       Elasticsearch;PostgreSQL;Redis
# 192                                                MySQL
# 228                                    Cassandra;MariaDB
# ...                                                  ...
# 88318              Microsoft SQL Server;MySQL;PostgreSQL
# 88431                                                NaN
# 88449                               PostgreSQL;Other(s):
# 88728  Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 88837  Elasticsearch;MongoDB;Microsoft SQL Server;Pos...
#
#                                   DatabaseDesireNextYear  \
# 51                                     PostgreSQL;SQLite
# 80                                                   NaN
# 190                       Elasticsearch;PostgreSQL;Redis
# 192                                                  NaN
# 228                                              MariaDB
# ...                                                  ...
# 88318  Elasticsearch;Firebase;MongoDB;MySQL;PostgreSQ...
# 88431                                                NaN
# 88449                                                NaN
# 88728  Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 88837                              Elasticsearch;MongoDB
#
#                                       PlatformWorkedWith  \
# 51                                                 Linux
# 80                    Android;Arduino;Linux;Raspberry Pi
# 190    Docker;Google Cloud Platform;Kubernetes;Linux;...
# 192         Arduino;Linux;Raspberry Pi;Windows;Other(s):
# 228                      Docker;Kubernetes;Linux;Windows
# ...                                                  ...
# 88318                       Android;Docker;Linux;Windows
# 88431                                                NaN
# 88449                                 Docker;Linux;Slack
# 88728                                                NaN
# 88837           Docker;Heroku;Raspberry Pi;Slack;Windows
#
#                                   PlatformDesireNextYear  \
# 51                                                 Linux
# 80                    Android;Arduino;Linux;Raspberry Pi
# 190    Docker;Google Cloud Platform;Kubernetes;Linux;...
# 192                 Linux;Raspberry Pi;Windows;Other(s):
# 228                  AWS;Docker;Kubernetes;Linux;Windows
# ...                                                  ...
# 88318  AWS;Docker;Google Cloud Platform;Kubernetes;Li...
# 88431                                                NaN
# 88449                                 Docker;Linux;Slack
# 88728                                                NaN
# 88837                                  Docker;Kubernetes
#
#                              WebFrameWorkedWith  \
# 51                                    Other(s):
# 80                                          NaN
# 190                             Django;React.js
# 192                                      jQuery
# 228                                         NaN
# ...                                         ...
# 88318  Angular/Angular.js;ASP.NET;Spring;Vue.js
# 88431                                       NaN
# 88449                                       NaN
# 88728                                       NaN
# 88837                                  React.js
#
#                          WebFrameDesireNextYear MiscTechWorkedWith  \
# 51                                    Other(s):            Node.js
# 80                                          NaN                NaN
# 190                             Django;React.js                NaN
# 192                                         NaN            Node.js
# 228                                         NaN            Ansible
# ...                                         ...                ...
# 88318  Angular/Angular.js;ASP.NET;Spring;Vue.js  .NET Core;Node.js
# 88431                                       NaN                NaN
# 88449                                       NaN       Apache Spark
# 88728                                       NaN                NaN
# 88837                                       NaN                NaN
#
#                                   MiscTechDesireNextYear  \
# 51                                                   NaN
# 80                                                   NaN
# 190                                                  NaN
# 192                                                  NaN
# 228                                              Ansible
# ...                                                  ...
# 88318                          Ansible;.NET Core;Node.js
# 88431                                                NaN
# 88449                                       Apache Spark
# 88728                                                NaN
# 88837  Apache Spark;Hadoop;Pandas;TensorFlow;Torch/Py...
#
#                                               DevEnviron        OpSys  \
# 51                           IntelliJ;Visual Studio Code  Linux-based
# 80                                                   Vim  Linux-based
# 190                               Vim;Visual Studio Code  Linux-based
# 192                 IntelliJ;Notepad++;Vim;Visual Studio      Windows
# 228                          Atom;IntelliJ;Notepad++;Vim      Windows
# ...                                                  ...          ...
# 88318      IntelliJ;Notepad++;PyCharm;Visual Studio Code      Windows
# 88431                                                NaN      Windows
# 88449         Atom;IPython / Jupyter;PyCharm;RStudio;Vim  Linux-based
# 88728  Eclipse;Emacs;Sublime Text;TextMate;Visual Stu...          NaN
# 88837            Atom;IntelliJ;IPython / Jupyter;PyCharm  Linux-based
#
#                                               Containers  \
# 51                               I do not use containers
# 80                               I do not use containers
# 190    Development;Testing;Production;Outside of work...
# 192                              I do not use containers
# 228    Development;Production;Outside of work, for pe...
# ...                                                  ...
# 88318  Development;Testing;Production;Outside of work...
# 88431                            I do not use containers
# 88449                     Development;Testing;Production
# 88728                            I do not use containers
# 88837                                        Development
#
#                                            BlockchainOrg  \
# 51     Accepting Bitcoin or other coins and tokens as...
# 80                                                   NaN
# 190                                                  NaN
# 192                                           Not at all
# 228                                                  NaN
# ...                                                  ...
# 88318                                         Not at all
# 88431                                                NaN
# 88449                                                NaN
# 88728            Non-currency applications of blockchain
# 88837                                                NaN
#
#                                             BlockchainIs BetterLife  \
# 51     Useful for decentralized currency (i.e., Bitcoin)         No
# 80     Useful for decentralized currency (i.e., Bitcoin)        Yes
# 190                                                  NaN        Yes
# 192                                        A passing fad        Yes
# 228    Useful across many domains and could change ma...        Yes
# ...                                                  ...        ...
# 88318                                                NaN        Yes
# 88431                                                NaN         No
# 88449                  An irresponsible use of resources         No
# 88728  Useful for immutable record keeping outside of...        Yes
# 88837                                                NaN         No
#
#                                        ITperson  OffOn  \
# 51                                         SIGH    Yes
# 80                                          Yes     No
# 190                                         Yes    Yes
# 192                                         Yes  What?
# 228                                    Also Yes    Yes
# ...                                         ...    ...
# 88318                                      SIGH    Yes
# 88431  Fortunately, someone else has that title  What?
# 88449                                      SIGH    Yes
# 88728  Fortunately, someone else has that title  What?
# 88837                                      SIGH  What?
#
#                     SocialMedia              Extraversion ScreenName  \
# 51                          NaN                   Neither   Username
# 80     I don't use social media  In real life (in person)   Username
# 190                      Reddit  In real life (in person)        NaN
# 192                     Twitter                   Neither      Login
# 228                     YouTube                   Neither      Login
# ...                         ...                       ...        ...
# 88318                    Reddit  In real life (in person)   Username
# 88431                  LinkedIn  In real life (in person)   Username
# 88449                  WhatsApp                   Neither     Handle
# 88728                     Hello                       NaN      Login
# 88837                  Facebook                    Online      Login
#
#              SOVisit1st                                        SOVisitFreq  \
# 51                 2011                Less than once per month or monthly
# 80                 2011                    A few times per month or weekly
# 190    I don't remember                             Multiple times per day
# 192                2014                              Daily or almost daily
# 228                2010                             Multiple times per day
# ...                 ...                                                ...
# 88318              2018                              Daily or almost daily
# 88431              2014                Less than once per month or monthly
# 88449              2011                               A few times per week
# 88728              2019  I have never visited Stack Overflow (before to...
# 88837              2015                              Daily or almost daily
#
#                                                SOVisitTo  \
# 51                    Find answers to specific questions
# 80                    Find answers to specific questions
# 190                   Find answers to specific questions
# 192    Find answers to specific questions;Learn how t...
# 228    Find answers to specific questions;Contribute ...
# ...                                                  ...
# 88318  Find answers to specific questions;Learn how t...
# 88431                 Find answers to specific questions
# 88449  Learn how to do things I didn’t necessarily lo...
# 88728                                                NaN
# 88837  Find answers to specific questions;Learn how t...
#
#                       SOFindAnswer                         SOTimeSaved  \
# 51         Less than once per week                                 NaN
# 80         Less than once per week            They were about the same
# 190    More than 10 times per week      Stack Overflow was much faster
# 192             3-5 times per week      Stack Overflow was much faster
# 228    More than 10 times per week            They were about the same
# ...                            ...                                 ...
# 88318          6-10 times per week  Stack Overflow was slightly faster
# 88431      Less than once per week  Stack Overflow was slightly faster
# 88449      Less than once per week            They were about the same
# 88728      Less than once per week      Stack Overflow was much faster
# 88837           1-2 times per week            They were about the same
#
#        SOHowMuchTime                  SOAccount  \
# 51      0-10 minutes                        Yes
# 80               NaN                        Yes
# 190      60+ minutes                        Yes
# 192    11-30 minutes  Not sure / can't remember
# 228              NaN                        Yes
# ...              ...                        ...
# 88318  31-60 minutes                        Yes
# 88431  11-30 minutes                        Yes
# 88449            NaN                        Yes
# 88728    60+ minutes                        NaN
# 88837            NaN                        Yes
#
#                                               SOPartFreq  \
# 51                   Less than once per month or monthly
# 80     I have never participated in Q&A on Stack Over...
# 190    I have never participated in Q&A on Stack Over...
# 192                                                  NaN
# 228                      A few times per month or weekly
# ...                                                  ...
# 88318  I have never participated in Q&A on Stack Over...
# 88431                Less than once per month or monthly
# 88449                              Daily or almost daily
# 88728                                                NaN
# 88837  I have never participated in Q&A on Stack Over...
#
#                                                   SOJobs  \
# 51                                                   Yes
# 80                                                   Yes
# 190    No, I didn't know that Stack Overflow had a jo...
# 192    No, I didn't know that Stack Overflow had a jo...
# 228                                                  Yes
# ...                                                  ...
# 88318  No, I knew that Stack Overflow had a job board...
# 88431  No, I knew that Stack Overflow had a job board...
# 88449                                                Yes
# 88728  No, I didn't know that Stack Overflow had a jo...
# 88837  No, I knew that Stack Overflow had a job board...
#
#                                                 EntTeams           SOComm  \
# 51     No, I've heard of them, but I am not part of a...   No, not really
# 80     No, I've heard of them, but I am not part of a...   No, not at all
# 190                  No, and I don't know what those are   No, not really
# 192                  No, and I don't know what those are   No, not really
# 228    No, I've heard of them, but I am not part of a...    Yes, somewhat
# ...                                                  ...              ...
# 88318  No, I've heard of them, but I am not part of a...   No, not at all
# 88431  No, I've heard of them, but I am not part of a...    Yes, somewhat
# 88449  No, I've heard of them, but I am not part of a...          Neutral
# 88728                                                Yes  Yes, definitely
# 88837  No, I've heard of them, but I am not part of a...          Neutral
#
#                                            WelcomeChange  \
# 51                 A lot less welcome now than last year
# 80               Just as welcome now as I felt last year
# 190              Just as welcome now as I felt last year
# 192              Just as welcome now as I felt last year
# 228              Just as welcome now as I felt last year
# ...                                                  ...
# 88318            Just as welcome now as I felt last year
# 88431            Just as welcome now as I felt last year
# 88449              A lot less welcome now than last year
# 88728  Not applicable - I did not use Stack Overflow ...
# 88837                                                NaN
#
#                                             SONewContent   Age Gender Trans  \
# 51                                                   NaN  22.0    Man    No
# 80                   Tech meetups or events in your area  28.0    Man    No
# 190            Tech articles written by other developers  28.0    Man    No
# 192         Courses on technologies you're interested in  29.0    Man    No
# 228    Tech articles written by other developers;Indu...   NaN    Man    No
# ...                                                  ...   ...    ...   ...
# 88318  Tech articles written by other developers;Cour...  22.0    Man    No
# 88431                                                NaN  42.0    Man    No
# 88449                                                NaN   NaN    NaN   NaN
# 88728       Courses on technologies you're interested in   NaN    NaN   NaN
# 88837                                                NaN  22.0  Woman    No
#
#                      Sexuality                     Ethnicity Dependents  \
# 51                         NaN                           NaN         No
# 80                         NaN  White or of European descent         No
# 190    Straight / Heterosexual  White or of European descent         No
# 192    Straight / Heterosexual  White or of European descent         No
# 228    Straight / Heterosexual  White or of European descent         No
# ...                        ...                           ...        ...
# 88318  Straight / Heterosexual  White or of European descent         No
# 88431  Straight / Heterosexual  White or of European descent        Yes
# 88449                      NaN                           NaN        NaN
# 88728                      NaN  White or of European descent        NaN
# 88837                      NaN  White or of European descent         No
#
#                 SurveyLength                  SurveyEase
# 51     Appropriate in length  Neither easy nor difficult
# 80     Appropriate in length                        Easy
# 190    Appropriate in length                        Easy
# 192    Appropriate in length                        Easy
# 228                 Too long                        Easy
# ...                      ...                         ...
# 88318               Too long  Neither easy nor difficult
# 88431               Too long  Neither easy nor difficult
# 88449  Appropriate in length                        Easy
# 88728  Appropriate in length                   Difficult
# 88837               Too long                        Easy
#
# [1922 rows x 85 columns]

# %%
filt = df['Country'] == 'Poland'
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# Facebook                    619
# YouTube                     366
# Reddit                      258
# I don't use social media    180
# Twitter                     164
# Instagram                    86
# LinkedIn                     72
# WhatsApp                     64
# Snapchat                      7
# VK ВКонта́кте                 4
# Hello                         1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().head(50)
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# Algeria              YouTube                      42
#                      Facebook                     41
#                      Twitter                      14
#                      LinkedIn                      9
#                      I don't use social media      7
#                      Instagram                     7
#                      Reddit                        2
#                      WhatsApp                      2
# Andorra              Facebook                      2
#                      I don't use social media      2
#                      Reddit                        1
#                      Snapchat                      1
#                      YouTube                       1
# Angola               Twitter                       2
#                      Facebook                      1
#                      YouTube                       1
# Antigua and Barbuda  YouTube                       2
#                      Facebook                      1
#                      Instagram                     1
#                      Twitter                       1
#                      VK ВКонта́кте                 1
# Argentina            WhatsApp                    202
#                      Twitter                      80
#                      YouTube                      62
#                      Instagram                    53
#                      Reddit                       50
#                      Facebook                     45
#                      I don't use social media     22
#                      LinkedIn                     16
# Armenia              Facebook                     38
#                      YouTube                      23
#                      LinkedIn                      5
#                      Instagram                     3
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts(normalize=True).loc['Russian Federation']
# Out:
# SocialMedia
# VK ВКонта́кте               0.303571
# YouTube                     0.207418
# I don't use social media    0.106456
# Reddit                      0.096154
# Twitter                     0.089286
# Instagram                   0.064560
# WhatsApp                    0.061813
# Facebook                    0.046016
# LinkedIn                    0.024038
# Snapchat                    0.000687
# Name: SocialMedia, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['Poland']
# Out:
# 32064.0

# %%
country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 63016.0

# %%
country_grp['ConvertedComp'].agg(['median', 'mean'])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
country_grp['ConvertedComp'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'Poland'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 751

# %%
country_grp['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-cda55dd00399> in <module>
# ----> 1 country_grp['LanguageWorkedWith'].str.contains('Python').sum()
#
# c:\users\mirek\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     578
#     579         raise AttributeError(
# --> 580             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     581         )
#     582
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_respodents = df['Country'].value_counts()
country_respodents
# Out:
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# Saint Kitts and Nevis                   1
# Saint Vincent and the Grenadines        1
# Sao Tome and Principe                   1
# Timor-Leste                             1
# Tonga                                   1
# Name: Country, Length: 179, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df = pd.concat([country_respodents, country_uses_python], axis='columns', sort=False)

# %%
python_df
# Out:
#                                   Country  LanguageWorkedWith
# United States                       20949               10083
# India                                9061                3105
# Germany                              5866                2451
# United Kingdom                       5737                2384
# Canada                               3395                1558
# ...                                   ...                 ...
# Saint Kitts and Nevis                   1                   0
# Saint Vincent and the Grenadines        1                   0
# Sao Tome and Principe                   1                   1
# Timor-Leste                             1                   1
# Tonga                                   1                   0
#
# [179 rows x 2 columns]

# %%
python_df.rename(columns={'Country': 'NumRespondents', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace=True)

# %%
python_df
# Out:
#                                   NumRespondents  NumKnowsPython
# United States                              20949           10083
# India                                       9061            3105
# Germany                                     5866            2451
# United Kingdom                              5737            2384
# Canada                                      3395            1558
# ...                                          ...             ...
# Saint Kitts and Nevis                          1               0
# Saint Vincent and the Grenadines               1               0
# Sao Tome and Principe                          1               1
# Timor-Leste                                    1               1
# Tonga                                          1               0
#
# [179 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython'] / python_df['NumRespondents']) * 100

# %%
python_df
# Out:
#                                   NumRespondents  NumKnowsPython  \
# United States                              20949           10083
# India                                       9061            3105
# Germany                                     5866            2451
# United Kingdom                              5737            2384
# Canada                                      3395            1558
# ...                                          ...             ...
# Saint Kitts and Nevis                          1               0
# Saint Vincent and the Grenadines               1               0
# Sao Tome and Principe                          1               1
# Timor-Leste                                    1               1
# Tonga                                          1               0
#
#                                   PctKnowsPython
# United States                          48.131176
# India                                  34.267741
# Germany                                41.783157
# United Kingdom                         41.554820
# Canada                                 45.891016
# ...                                          ...
# Saint Kitts and Nevis                   0.000000
# Saint Vincent and the Grenadines        0.000000
# Sao Tome and Principe                 100.000000
# Timor-Leste                           100.000000
# Tonga                                   0.000000
#
# [179 rows x 3 columns]

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)

# %%
python_df.head(50)
# Out:
#                                   NumRespondents  NumKnowsPython  \
# Niger                                          1               1
# Dominica                                       1               1
# Timor-Leste                                    1               1
# Sao Tome and Principe                          1               1
# Turkmenistan                                   7               6
# Mauritania                                     7               5
# Bahamas                                        3               2
# Guyana                                         3               2
# Guinea                                         3               2
# Uganda                                        72              47
# Iceland                                       49              30
# Benin                                          5               3
# Haiti                                          5               3
# Namibia                                        5               3
# Congo, Republic of the...                      7               4
# Oman                                          11               6
# Cuba                                          30              16
# Republic of Korea                             39              20
# South Korea                                  160              80
# Sierra Leone                                   2               1
# Monaco                                         4               2
# Bhutan                                         2               1
# San Marino                                     2               1
# Seychelles                                     2               1
# Chile                                        206             102
# Finland                                      546             266
# Kenya                                        249             120
# United States                              20949           10083
# Israel                                       952             457
# Ecuador                                       82              39
# Taiwan                                       187              88
# Mongolia                                      17               8
# Montenegro                                    17               8
# Switzerland                                  978             460
# United Republic of Tanzania                   32              15
# Hong Kong (S.A.R.)                           188              88
# Japan                                        391             182
# Maldives                                      13               6
# Canada                                      3395            1558
# Singapore                                    303             139
# New Zealand                                  524             236
# China                                        664             297
# Honduras                                      27              12
# France                                      2391            1054
# Iraq                                          39              17
# Thailand                                     214              92
# Democratic Republic of the Congo               7               3
# Nepal                                        237             101
# Estonia                                      195              82
# Russian Federation                          1694             708
#
#                                   PctKnowsPython
# Niger                                 100.000000
# Dominica                              100.000000
# Timor-Leste                           100.000000
# Sao Tome and Principe                 100.000000
# Turkmenistan                           85.714286
# Mauritania                             71.428571
# Bahamas                                66.666667
# Guyana                                 66.666667
# Guinea                                 66.666667
# Uganda                                 65.277778
# Iceland                                61.224490
# Benin                                  60.000000
# Haiti                                  60.000000
# Namibia                                60.000000
# Congo, Republic of the...              57.142857
# Oman                                   54.545455
# Cuba                                   53.333333
# Republic of Korea                      51.282051
# South Korea                            50.000000
# Sierra Leone                           50.000000
# Monaco                                 50.000000
# Bhutan                                 50.000000
# San Marino                             50.000000
# Seychelles                             50.000000
# Chile                                  49.514563
# Finland                                48.717949
# Kenya                                  48.192771
# United States                          48.131176
# Israel                                 48.004202
# Ecuador                                47.560976
# Taiwan                                 47.058824
# Mongolia                               47.058824
# Montenegro                             47.058824
# Switzerland                            47.034765
# United Republic of Tanzania            46.875000
# Hong Kong (S.A.R.)                     46.808511
# Japan                                  46.547315
# Maldives                               46.153846
# Canada                                 45.891016
# Singapore                              45.874587
# New Zealand                            45.038168
# China                                  44.728916
# Honduras                               44.444444
# France                                 44.081974
# Iraq                                   43.589744
# Thailand                               42.990654
# Democratic Republic of the Congo       42.857143
# Nepal                                  42.616034
# Estonia                                42.051282
# Russian Federation                     41.794569

# %%
python_df.loc['Poland']
# Out:
# NumRespondents    1922.000000
# NumKnowsPython     751.000000
# PctKnowsPython      39.073881
# Name: Poland, dtype: float64
